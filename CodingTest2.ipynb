# %% [markdown]
# Problem: Find the Missing Number Problem Statement You are given an array containing N distinct numbers from 1 to N+1. Exactly one number is missing from the sequence. Find and return the missing number. Input An array of distinct integers. The numbers belong to the range: 1 to N+1 where N is the number of elements in the array. Output Print the missing number. Examples Example 1 Input: 1 2 4 5 6 Output: 3 Example 2 Input: 1 2 3 5 Output: 4 Example 3 Input: 2 3 1 5 Output: 4 Explanation For the input: 2 3 1 5 The complete sequence should be: 1 2 3 4 5 The missing number is: 4 Constraints All numbers are distinct. Exactly one number is missing. Numbers are in the range 1 to N+1. The array may contain a large number of elements. Expected Complexity Try to achieve: Time Complexity: O(n) Space Complexity: O(1) Extra space should not be used for storing another copy of the array or maintaining a separate lookup structure.
#
# Instructions:
# You can solve the problems using any programming language of your choice.
# There is no programming language restriction for this assessment.
# Write clean, readable, and well-structured code.
# Your solution should handle the given examples as well as additional test cases.
# Consider the time and space complexity of your solution.
# Create a Git repository for your solution.
# Push your complete solution/code to the Git repository.
# Make sure the repository is accessible to the evaluator.
# Submit the Git repository link along with your assessment.
# The repository should contain:
# Source code for both problems
# A README file explaining how to run the solution
# Any required input/output instructions
# Do not upload unnecessary files, build artifacts, IDE-specific files, or dependency folders.
# You may use standard documentation/reference material for syntax, but the solution should be your own implementation.
# # Find the Missing Number
#
# def find_missing_number(arr):
#     n = len(arr)
#
#     # Sum of numbers from 1 to N+1
#     expected_sum = (n + 1) * (n + 2) // 2
#
#     # Sum of elements in the array
#     actual_sum = sum(arr)
#
#     return expected_sum - actual_sum
#
#
# # Input
# arr = list(map(int, input().split()))
#
# # Output
# print(find_missing_number(arr))

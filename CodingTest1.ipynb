# %% [markdown]
# Problem - First Non-Repeating Character Problem Statement
# Given a string, find the first character that appears exactly once in the string. If every character appears more than once, return -1. The comparison should be case-sensitive. Input A single string containing characters. Output Print the first character that occurs exactly once. If no such character exists, print: -1 Examples Example 1 Input: swiss Output: w Explanation: s appears multiple times. w appears only once. Therefore, the first non-repeating character is w. Example 2 Input: aabbcc Output: -1 Explanation: Every character appears more than once. Example 3 Input: programming Output: p Constraints The string may contain uppercase and lowercase letters. The string may contain digits and special characters. The solution should work efficiently for large input sizes. Expected Complexity Try to achieve: Time Complexity: O(n) where n is the length of the string.
#
# # Instructions:
# Additional Requirement -
# Your implementation should work correctly for:
# Empty string
# String containing only one character
# String where all characters are repeated
# String containing spaces
# String containing uppercase and lowercase characters
# # General Instructions
# You can solve the problems using any programming language of your choice.
# There is no programming language restriction for this assessment.
# Write clean, readable, and well-structured code.
# Your solution should handle the given examples as well as additional test cases.
# Consider the time and space complexity of your solution.
# Create a Git repository for your solution.
# Push your complete solution/code to the Git repository.
# Make sure the repository is accessible to the evaluator.
# Submit the Git repository link along with your assessment.
# The repository should contain:
# Source code for both problems
# A README file explaining how to run the solution
# Any required input/output instructions
# Do not upload unnecessary files, build artifacts, IDE-specific files, or dependency folders.
# You may use standard documentation/reference material for syntax, but the solution should be your own implementation.

# %%
str1=input()


freq = {}
for i in str1:
    freq[i]=freq.get(i, 0)+1
    

for i in str1:
    if(freq[i]==1):
        print(i)
        break
else:
    print(-1)
# Out:
# -1
